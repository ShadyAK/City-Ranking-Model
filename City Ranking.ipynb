# %% [markdown]
# ### Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data import and analysis

# %%
data=pd.read_csv("city_ranking.csv")

# %%
data.head()
# Out:
#         city         country  Employment Score  Startup Score  Tourism Score  \
# 0     Berlin         Germany               4.8            9.0            6.2
# 1   Montréal          Canada               6.0            8.1            5.7
# 2     London  United Kingdom               6.6            9.8            9.8
# 3  Amsterdam     Netherlands               7.6            8.3            8.7
# 4    Toronto          Canada               6.3            9.5            4.4
#
#    Housing Score  Food Ranking  Transport Score  Health Rank  \
# 0            5.2           7.2              7.1          3.9
# 1            6.4           5.1              3.6          7.4
# 2            0.5           2.2              7.2          4.4
# 3            0.6           1.7              5.7          6.9
# 4            2.7           6.1              4.3          7.4
#
#    Internet Speed Score  University Score  Access to Contraceptive Score  \
# 0                   5.0               4.9                            6.9
# 1                   5.1               5.8                            8.6
# 2                   4.7              10.0                            9.5
# 3                   4.5               5.0                            7.9
# 4                   7.1               5.2                            8.6
#
#    Gender Equality Score  Immigration Tolerence  Personal Freedom and Choice  \
# 0                    7.5                    8.4                          7.8
# 1                    7.0                    9.9                          8.1
# 2                    7.1                    8.7                          9.6
# 3                    5.5                    8.5                         10.0
# 4                    7.0                    9.9                          9.4
#
#    LGBT friendly Score  Nightlife Score  Beer Ranking  Festival Ranking  Total
# 0                  9.7             10.0           7.0               8.0   7.14
# 1                  9.6              8.8           5.1               9.0   7.10
# 2                  9.4              9.4           2.5               7.5   6.71
# 3                  9.9              8.6           4.8               9.7   6.63
# 4                  9.8              4.5           3.6               9.4   6.60

# %% [markdown]
# ### Let's see some statistical details of the given data

# %%
data.describe()
# Out:
#        Employment Score  Startup Score  Tourism Score  Housing Score  \
# count        110.000000     110.000000     110.000000     110.000000
# mean           4.972727       4.994545       5.000000       5.000909
# std            2.909646       2.931037       2.922705       2.922343
# min            0.000000       0.000000       0.000000       0.000000
# 25%            2.500000       2.525000       2.525000       2.525000
# 50%            5.000000       5.000000       5.000000       5.000000
# 75%            7.450000       7.475000       7.475000       7.475000
# max           10.000000      10.000000      10.000000      10.000000
#
#        Food Ranking  Transport Score  Health Rank  Internet Speed Score  \
# count    110.000000       110.000000   110.000000            110.000000
# mean       5.000909         4.304545     4.841818              4.992727
# std        2.924101         2.232183     2.924850              2.925676
# min        0.000000         0.000000     0.000000              0.000000
# 25%        2.525000         2.700000     1.900000              2.525000
# 50%        5.000000         4.250000     4.400000              5.000000
# 75%        7.475000         6.000000     7.400000              7.475000
# max       10.000000        10.000000    10.000000             10.000000
#
#        University Score  Access to Contraceptive Score  Gender Equality Score  \
# count        110.000000                     110.000000             110.000000
# mean           3.580000                       7.210909               5.416364
# std            2.496706                       1.982647               2.031429
# min            1.000000                       0.000000               0.000000
# 25%            1.000000                       6.900000               4.100000
# 50%            3.500000                       7.500000               5.250000
# 75%            5.375000                       8.400000               7.100000
# max           10.000000                      10.000000              10.000000
#
#        Immigration Tolerence  Personal Freedom and Choice  \
# count             110.000000                   110.000000
# mean                7.236364                     4.914545
# std                 2.408423                     2.918302
# min                 0.000000                     0.000000
# 25%                 6.600000                     2.525000
# 50%                 8.300000                     5.000000
# 75%                 8.700000                     7.200000
# max                10.000000                    10.000000
#
#        LGBT friendly Score  Nightlife Score  Beer Ranking  Festival Ranking  \
# count           110.000000       110.000000    110.000000        110.000000
# mean              5.000000         4.992727      5.067273          4.517273
# std               2.922705         2.926585      2.926284          3.169026
# min               0.000000         0.000000      0.000000          0.000000
# 25%               2.525000         2.525000      2.425000          0.700000
# 50%               5.000000         5.000000      5.100000          4.400000
# 75%               7.475000         7.475000      7.475000          7.275000
# max              10.000000        10.000000     10.000000         10.000000
#
#             Total
# count  110.000000
# mean     5.125545
# std      0.780482
# min      3.210000
# 25%      4.695000
# 50%      5.185000
# 75%      5.632500
# max      7.140000

# %% [markdown]
# ## Points to be noted
# 1. Almost all observation's mean lie around 5.
# 2. Most of the country have a good Access to Contraceptive and Immigration Tolerence score.

# %% [markdown]
# ## Now we will give a quick look to the cities having the best feature score among the dataset

# %%
features=data.columns[2:-1]
countries=[]
for i in range(len(features)):
    indexes=np.where(data.iloc[:,i+2]==max(data.iloc[:,i+2]))
    indexes=indexes[0].tolist()                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 
    print("City/ies with the best score of the feature :",features[i])
    print("|City Name X Country|")
    for j in range(len(indexes)):
        print(data.iloc[indexes[j],0]," ",data.iloc[indexes[j],1],features[i],":",data.iloc[indexes[j],i+2])
        #countries.append(data.iloc[indexes[j],1])
    print("--------------------------------------------------------------------")
# Out:
# City/ies with the best score of the feature : Employment Score
# |City Name X Country|
# Beijing   China Employment Score : 10.0
# --------------------------------------------------------------------
# City/ies with the best score of the feature : Startup Score
# |City Name X Country|
# New York City   USA Startup Score : 10.0
# --------------------------------------------------------------------
# City/ies with the best score of the feature : Tourism Score
# |City Name X Country|
# Hong Kong   Hong Kong SAR Tourism Score : 10.0
# --------------------------------------------------------------------
# City/ies with the best score of the feature : Housing Score
# |City Name X Country|
# Guadalajara   Mexico Housing Score : 10.0
# --------------------------------------------------------------------
# City/ies with the best score of the feature : Food Ranking
# |City Name X Country|
# Bangkok   Thailand Food Ranking : 10.0
# --------------------------------------------------------------------
# City/ies with the best score of the feature : Transport Score
# |City Name X Country|
# Oslo   Norway Transport Score : 10.0
# --------------------------------------------------------------------
# City/ies with the best score of the feature : Health Rank
# |City Name X Country|
# Tokyo   Japan Health Rank : 10.0
# Osaka   Japan Health Rank : 10.0
# --------------------------------------------------------------------
# City/ies with the best score of the feature : Internet Speed Score
# |City Name X Country|
# Seoul   South Korea Internet Speed Score : 10.0
# --------------------------------------------------------------------
# City/ies with the best score of the feature : University Score
# |City Name X Country|
# London   United Kingdom University Score : 10.0
# --------------------------------------------------------------------
# City/ies with the best score of the feature : Access to Contraceptive Score
# |City Name X Country|
# Beijing   China Access to Contraceptive Score : 10.0
# Shanghai   China Access to Contraceptive Score : 10.0
# --------------------------------------------------------------------
# City/ies with the best score of the feature : Gender Equality Score
# |City Name X Country|
# Oslo   Norway Gender Equality Score : 10.0
# Bergen   Norway Gender Equality Score : 10.0
# --------------------------------------------------------------------
# City/ies with the best score of the feature : Immigration Tolerence
# |City Name X Country|
# Auckland   New Zealand Immigration Tolerence : 10.0
# Wellington   New Zealand Immigration Tolerence : 10.0
# Christchurch   New Zealand Immigration Tolerence : 10.0
# --------------------------------------------------------------------
# City/ies with the best score of the feature : Personal Freedom and Choice
# |City Name X Country|
# Amsterdam   Netherlands Personal Freedom and Choice : 10.0
# --------------------------------------------------------------------
# City/ies with the best score of the feature : LGBT friendly Score
# |City Name X Country|
# Madrid   Spain LGBT friendly Score : 10.0
# --------------------------------------------------------------------
# City/ies with the best score of the feature : Nightlife Score
# |City Name X Country|
# Berlin   Germany Nightlife Score : 10.0
# --------------------------------------------------------------------
# City/ies with the best score of the feature : Beer Ranking
# |City Name X Country|
# Beijing   China Beer Ranking : 10.0
# --------------------------------------------------------------------
# City/ies with the best score of the feature : Festival Ranking
# |City Name X Country|
# Miami   USA Festival Ranking : 10.0
# --------------------------------------------------------------------

# %% [markdown]
# ## Country wise scores

# %%
grouped_data=data.groupby(["country"])
for i in range(len(features)):
    print("Feature :",features[i])
    series=grouped_data[features[i]].agg(np.mean)
    country_name_max_score=series[series==max(series)].index[0]
    max_score=max(series)
    print("Country with max score :",country_name_max_score,"|| Score: ",max_score)
    print("Number of observations in the country:",len(data[data.iloc[:,1]==country_name_max_score].iloc[:,0]))
    print("------------------------------------------------")
# Out:
# Feature : Employment Score
# Country with max score : Russia || Score:  9.6
# Number of observations in the country: 1
# ------------------------------------------------
# Feature : Startup Score
# Country with max score : Singapore || Score:  9.1
# Number of observations in the country: 1
# ------------------------------------------------
# Feature : Tourism Score
# Country with max score : Hong Kong SAR || Score:  10.0
# Number of observations in the country: 1
# ------------------------------------------------
# Feature : Housing Score
# Country with max score : Colombia || Score:  9.75
# Number of observations in the country: 2
# ------------------------------------------------
# Feature : Food Ranking
# Country with max score : Thailand || Score:  10.0
# Number of observations in the country: 1
# ------------------------------------------------
# Feature : Transport Score
# Country with max score : Russia || Score:  7.3
# Number of observations in the country: 1
# ------------------------------------------------
# Feature : Health Rank
# Country with max score : Japan || Score:  10.0
# Number of observations in the country: 2
# ------------------------------------------------
# Feature : Internet Speed Score
# Country with max score : South Korea || Score:  10.0
# Number of observations in the country: 1
# ------------------------------------------------
# Feature : University Score
# Country with max score : South Korea || Score:  9.6
# Number of observations in the country: 1
# ------------------------------------------------
# Feature : Access to Contraceptive Score
# Country with max score : China || Score:  10.0
# Number of observations in the country: 2
# ------------------------------------------------
# Feature : Gender Equality Score
# Country with max score : Norway || Score:  10.0
# Number of observations in the country: 2
# ------------------------------------------------
# Feature : Immigration Tolerence
# Country with max score : New Zealand || Score:  10.0
# Number of observations in the country: 3
# ------------------------------------------------
# Feature : Personal Freedom and Choice
# Country with max score : Finland || Score:  9.8
# Number of observations in the country: 1
# ------------------------------------------------
# Feature : LGBT friendly Score
# Country with max score : Finland || Score:  9.1
# Number of observations in the country: 1
# ------------------------------------------------
# Feature : Nightlife Score
# Country with max score : Brazil || Score:  9.55
# Number of observations in the country: 2
# ------------------------------------------------
# Feature : Beer Ranking
# Country with max score : Colombia || Score:  9.850000000000001
# Number of observations in the country: 2
# ------------------------------------------------
# Feature : Festival Ranking
# Country with max score : Denmark || Score:  9.0
# Number of observations in the country: 1
# ------------------------------------------------

# %% [markdown]
# # Creating Model

# %% [markdown]
# ## Algorithm
# 1. The algorithm is based on the concept of adding extra values to the ratings of the features wanted by the user in the city
# 2. The results will give more waitage to the user requirements.
# 3. Other features will not be discarded as other features are not important to the user but will serve a better recommendation and experience to the user(practically)
# 4. The bias value is based on practical experimentation and observations , so the model might not give perfect results but is doing the best taking the given time to create the model in consideration.There is definately scope of improvement.
# 5. Due to the lack of the user data the model had to be created from the scratch.

# %% [markdown]
# ## Explanation of Bias Multiplier
# The bias in this model is defined by a function i.e. [10xi/len(features) for i in range(0,len(features)x3,3)] which will result in values [0,30/18,120/18,....]. The bias value for the first priority of the feature user wants in the predictions will be the biggest bias in the list i.e. the bias value at -1 index.
# [10xi/len(features) for i in range(0,len(features)x3,3)] :   range(0,len(features)x3,3) this part of the function makes sure that within the priorities the first priority should always have a greater impact on the final result and the impact of all priorities should be order wise according to the user.

# %%
def model(feature_list):
    biases=[10*i/len(features) for i in range(0,len(features)*3,3)]
    biases.reverse()
    final_scores={}
    for i in range(data.shape[0]):
        row_score=data.iloc[i:i+1,2:-1].sum(axis=1)[i] #Pandas series index will be set as i so extraction of numeric from series we have to specify the index
        for j in range(len(feature_list)):
            bias_add=data.iloc[i,feature_list[j]+2]*biases[j]
            row_score+=bias_add
        final_scores[row_score]=data.iloc[i,0]    
    return final_scores
    #final_scores

# %% [markdown]
# ## Taking the user input

# %%
print("Enter the numbers respective to the features you want in the city \nNote:Enter them according to the necissity rank i.e. more important first")
for i in range(len(features)):
    print(i,features[i])
print("\n\n\nEnter them as inline order example:'1 4 5 6 3'")
# Out:
# Enter the numbers respective to the features you want in the city
# Note:Enter them according to the necissity rank i.e. more important first
# 0 Employment Score
# 1 Startup Score
# 2 Tourism Score
# 3 Housing Score
# 4 Food Ranking
# 5 Transport Score
# 6 Health Rank
# 7 Internet Speed Score
# 8 University Score
# 9 Access to Contraceptive Score
# 10 Gender Equality Score
# 11 Immigration Tolerence
# 12 Personal Freedom and Choice
# 13 LGBT friendly Score
# 14 Nightlife Score
# 15 Beer Ranking
# 16 Festival Ranking
#
#
#
# Enter them as inline order example:'1 4 5 6 3'

# %%
while True:
    input_data=input()
    try:
        input_data=list(map(int,input_data.split(" ")))
        break
    except:
        print("---------------------------------")
        print("oops take care of spaces and do not give extra spaces at the end of the input")
        print("Enter input as example below \n6 7 8 9 2 1")
        print("---------------------------------")
# Out:
# 1 0 5 11

# %% [markdown]
# ### Lets assume a person wants to setup a business abroad , his requirements are Startup Score,Employment Score,Transport,Immigration Tollerance
# * Input:1 0 5 11

# %%
scores=model(input_data)
sorted_keys=sorted(scores,reverse=True)
sorted_keys[:5]
suggestions=[]
index=[]
for i in range(5):
    index.append(data[data.iloc[:,0]==scores[sorted_keys[i]]].index.tolist()[0])
    suggestions.append(scores[sorted_keys[i]])
print("Top 5 recommended cities for you")
print(suggestions) 
data.iloc[index,:]
# Out:
# Top 5 recommended cities for you
# ['San Francisco', 'New York City', 'Boston', 'London', 'Austin']
#              city         country  Employment Score  Startup Score  \
# 12  San Francisco             USA               9.9            9.9
# 7   New York City             USA               7.9           10.0
# 68         Boston             USA               9.5            9.6
# 2          London  United Kingdom               6.6            9.8
# 13         Austin             USA               9.8            9.4
#
#     Tourism Score  Housing Score  Food Ranking  Transport Score  Health Rank  \
# 12            5.5            0.0           0.9              8.3          1.9
# 7             9.4            0.1           0.6              8.0          1.9
# 68            2.1            0.2           2.3              6.0          1.9
# 2             9.8            0.5           2.2              7.2          4.4
# 13            3.1            2.5           3.8              3.7          1.9
#
#     Internet Speed Score  University Score  Access to Contraceptive Score  \
# 12                   6.7               6.9                            7.8
# 7                    7.4               7.9                            7.8
# 68                   7.5               8.1                            7.8
# 2                    4.7              10.0                            9.5
# 13                   8.8               1.0                            7.8
#
#     Gender Equality Score  Immigration Tolerence  Personal Freedom and Choice  \
# 12                    4.5                    8.5                          6.7
# 7                     4.5                    8.5                          5.5
# 68                    4.5                    8.5                          3.6
# 2                     7.1                    8.7                          9.6
# 13                    4.5                    8.5                          5.5
#
#     LGBT friendly Score  Nightlife Score  Beer Ranking  Festival Ranking  \
# 12                  8.3              6.4           2.8               9.0
# 7                   8.6              8.9           2.8               9.4
# 68                  3.7              0.6           2.8               9.3
# 2                   9.4              9.4           2.5               7.5
# 13                  7.2              4.1           6.8               8.9
#
#     Total
# 12   6.04
# 7    6.25
# 68   4.86
# 2    6.71
# 13   6.03

# %%
def plot_figures(suggestions):
    f, axes = plt.subplots(1, 5, figsize=(18, 5), sharex=True,sharey=True)
    plt.figure(figsize=(12,5))
    for i in range(5):
        col=i
        x=features[input_data].tolist()
        x.append("Overall City Score")
        #print(x)
        y=data.loc[index[i],features[input_data]].tolist()
        y.append(data.iloc[index[i],-1])
        #print(y)
        g=sns.barplot(x=x,y=y,ax=axes[col])
        g.set_xticklabels(labels=x,rotation=90)
        g.set_title(suggestions[i])

# %% [markdown]
# ## Visualizing the recommendations

# %%
plot_figures(suggestions)

# %% [markdown]
# *Now the user can decide on himself what features he can compromise a bit and which city would be best suited by looking at this visual representation of the recommendations.
